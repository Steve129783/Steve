# %%
import numpy as np
import cv2
import json
from pathlib import Path
from PIL import Image, ImageDraw
import math

def split_and_label_small_defects(binary_mask, min_area=1, max_diameter=7):
    """
    输入：
      - binary_mask: uint8 二值图 (255 表示候选缺陷像素, 0 背景)
      - min_area: 连通块最小面积，低于此丢弃
      - max_diameter: 最终允许的小圆最大直径
    输出：
      - defect_circles: [[cx, cy], [cx+r, cy]] 列表，每个圆直径 ≤ max_diameter
    """
    defect_circles = []
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(binary_mask)
    for lbl in range(1, num_labels):
        area = stats[lbl, cv2.CC_STAT_AREA]
        if area < min_area:
            continue

        single_mask = (labels == lbl).astype(np.uint8) * 255
        cnts, _ = cv2.findContours(single_mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        if not cnts:
            continue
        cnt = cnts[0]
        (cx, cy), r = cv2.minEnclosingCircle(cnt)
        diameter = 2 * r

        if diameter <= max_diameter:
            defect_circles.append([[float(cx), float(cy)], [float(cx + r), float(cy)]])
            continue

        # 拆分：距离变换 + 分水岭
        single_bin = single_mask.copy()
        single_bin[single_bin > 0] = 1
        dist = cv2.distanceTransform(single_bin, distanceType=cv2.DIST_L2, maskSize=5)
        _, sure_fg = cv2.threshold(dist, dist.max() * 0.6, 255, 0)
        sure_fg = np.uint8(sure_fg)
        num_fg, markers = cv2.connectedComponents(sure_fg)
        markers = markers + 1
        markers[single_bin == 0] = 0

        single_color = cv2.cvtColor(single_mask, cv2.COLOR_GRAY2BGR)
        cv2.watershed(single_color, markers)

        for marker_id in range(2, num_fg + 2):
            sub_region = np.uint8(markers == marker_id)
            if sub_region.sum() < min_area:
                continue
            sub_cnts, _ = cv2.findContours(sub_region, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
            if not sub_cnts:
                continue
            sc = sub_cnts[0]
            (scx, scy), sr = cv2.minEnclosingCircle(sc)
            sdiam = 2 * sr
            if sdiam > max_diameter:
                sr = max_diameter / 2.0
            defect_circles.append([[float(scx), float(scy)], [float(scx + sr), float(scy)]])
    return defect_circles

def circle_intersection_area(c1, c2):
    x0, y0, r0 = c1
    x1, y1, r1 = c2
    d = math.hypot(x1 - x0, y1 - y0)
    if d >= r0 + r1:
        return 0.0
    if d <= abs(r0 - r1):
        return math.pi * min(r0, r1)**2

    # 下面是两圆部分重叠时的计算
    r0_sq, r1_sq, d_sq = r0**2, r1**2, d**2
    alpha = math.acos((d_sq + r0_sq - r1_sq) / (2*d*r0)) * 2
    beta  = math.acos((d_sq + r1_sq - r0_sq) / (2*d*r1)) * 2
    area0 = 0.5 * r0_sq * (alpha - math.sin(alpha))
    area1 = 0.5 * r1_sq * (beta  - math.sin(beta))
    return area0 + area1

tif_dir  = Path(r'D:\Study\Postgraduate\S2\Project\Code\Resource\Original\1_2_3_4\1')
json_dir = Path(r'D:\Study\Postgraduate\S2\Project\Code\Resource\Middle Stage B\1_2_3_4\1')
output_dir = Path(r'D:\Study\Postgraduate\S2\Project\Code\Resource\Test')
output_dir.mkdir(parents=True, exist_ok=True)

brightness_threshold = 255  # 根据需要调整

# 获取所有 tif
fnames = [p for p in tif_dir.iterdir() if p.suffix.lower() == '.tif']
for image_path in fnames:
    # 对应 JSON 名称
    json_filename = f"{image_path.stem}_mainbody.json"
    json_path = json_dir / json_filename
    if not json_path.exists():
        print(f"Skip, not found: {json_filename}")
        continue

    # 读取原始标注
    with json_path.open('r', encoding='utf-8') as f:
        ann = json.load(f)

    img = Image.open(image_path).convert("RGB")
    w, h = img.size

    # 生成主体掩码
    mask_mb = np.zeros((h, w), dtype=np.uint8)
    for s in ann["shapes"]:
        if s["label"].lower() == "main body":
            tmp = Image.new("L", (w, h), 0)
            draw = ImageDraw.Draw(tmp)
            pts = [tuple(p) for p in s["points"]]
            draw.polygon(pts, fill=1)
            mask_mb[np.array(tmp, bool)] = 1

    mb_uint8 = (mask_mb * 255).astype(np.uint8)
    dist_to_border = cv2.distanceTransform(mb_uint8, distanceType=cv2.DIST_L2, maskSize=5)
    gray = cv2.imread(str(image_path), cv2.IMREAD_GRAYSCALE)

    # 腐蚀去边缘
    erode_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (7, 7))
    inner_mask = cv2.erode(mask_mb, erode_kernel, iterations=1)
    gray_masked = gray.copy()
    gray_masked[inner_mask != 1] = 255

    # 分块自适应阈值
    bw_combined = np.zeros((h, w), dtype=np.uint8)
    x_quarters = [0, w//4, 2*w//4, 3*w//4, w]
    y_quarters = [0, h//4, 2*h//4, 3*h//4, h]
    for i in range(4):
        for j in range(4):
            x0, x1 = x_quarters[i], x_quarters[i+1]
            y0, y1 = y_quarters[j], y_quarters[j+1]
            sub_mask = np.zeros((h, w), dtype=np.uint8)
            sub_mask[y0:y1, x0:x1] = 1
            mb_sub = (inner_mask==1) & (sub_mask==1)
            pixels = gray[mb_sub]
            if pixels.size == 0:
                continue
            median_val = float(np.median(pixels))
            thresh_val = int(median_val * 0.925)
            bw = np.zeros((h, w), dtype=np.uint8)
            bw[(mb_sub) & (gray_masked < thresh_val)] = 255
            bw_combined = cv2.bitwise_or(bw_combined, bw)

    # 连通组件过滤
    num_labels, labels, stats, _ = cv2.connectedComponentsWithStats(bw_combined)
    mask_defect = np.zeros((h, w), dtype=np.uint8)
    for k in range(1, num_labels):
        if stats[k, cv2.CC_STAT_AREA] >= 1:
            mask_defect[labels==k] = 255

    # 查找轮廓并拟圆
    contours, _ = cv2.findContours(mask_defect, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    defect_circles = []
    for cnt in contours:
        if cv2.contourArea(cnt) < 1:
            continue
        (cx, cy), r = cv2.minEnclosingCircle(cnt)
        diameter = 2 * r
        cx_i, cy_i = int(round(cx)), int(round(cy))
        dist_center = dist_to_border[cy_i, cx_i]
        if diameter <= 9:
            mask_c = np.zeros((h, w), dtype=np.uint8)
            cv2.circle(mask_c, (cx_i, cy_i), int(round(r)), 1, -1)
            vals = gray[mask_c==1]
            if vals.size>0 and vals.min()<=brightness_threshold:
                defect_circles.append([[float(cx), float(cy)], [float(cx+r), float(cy)]])
        else:
            if dist_center < 15:
                continue
            single = np.zeros((h, w), dtype=np.uint8)
            cv2.drawContours(single, [cnt], -1, 255, -1)
            splits = split_and_label_small_defects(single, min_area=2, max_diameter=9
            )
            for sc in splits:
                scx, scy = int(round(sc[0][0])), int(round(sc[0][1]))
                sr = abs(sc[1][0]-sc[0][0])
                mask_c = np.zeros((h, w), dtype=np.uint8)
                cv2.circle(mask_c, (scx, scy), int(round(sr)), 1, -1)
                vals = gray[mask_c==1]
                if vals.size>0 and vals.min()<=brightness_threshold:
                    defect_circles.append(sc)

    # 去重重叠圆
    circles_params = [(c[0][0], c[0][1], abs(c[1][0]-c[0][0])) for c in defect_circles]
    keep = [True]*len(circles_params)
    for i in range(len(circles_params)):
        if not keep[i]: continue
        for j in range(i+1, len(circles_params)):
            if not keep[j]: continue
            ai = math.pi*circles_params[i][2]**2
            aj = math.pi*circles_params[j][2]**2
            inter = circle_intersection_area(circles_params[i], circles_params[j])
            if inter and inter/min(ai, aj)>=0.1:
                keep[j] = False
    filtered = [defect_circles[k] for k in range(len(defect_circles)) if keep[k]]

    # 构建新 JSON，保证 imagePath 指向 tif_dir 中的源文件
    new_shapes = [s for s in ann["shapes"] if s["label"].lower()=="main body"]
    for pts in filtered:
        new_shapes.append({
            "label": "defect",
            "points": pts,
            "group_id": None,
            "shape_type": "circle",
            "flags": {}
        })
    labelme = {
        "version": ann.get("version", "5.2.1"),
        "flags": ann.get("flags", {}),
        # 关键修改：用绝对 tif 路径，确保打开时定位正确
        "imagePath": str(image_path),
        "imageHeight": h,
        "imageWidth": w,
        # 不嵌入 imageData，留空
        "imageData": None,
        "shapes": new_shapes
    }

    # 写出 JSON
    out_path = output_dir / image_path.with_suffix('.json').name
    with out_path.open('w', encoding='utf-8') as f:
        json.dump(labelme, f, ensure_ascii=False, indent=2)
    print(f"✓ Saved JSON: {out_path.name}")

    # 保存含缺陷全图掩码（0 背景，1 主体，2 缺陷）
    full_mask = mask_mb.copy()
    for pts in filtered:
        cx, cy = int(round(pts[0][0])), int(round(pts[0][1]))
        r = abs(pts[1][0]-pts[0][0])
        cv2.circle(full_mask, (cx, cy), int(round(r)), 2, -1)
    mask_path = output_dir / f"{image_path.stem}.npy"
    np.save(str(mask_path), full_mask)
    print(f"✓ Saved mask: {mask_path.name}")
# Out:
# ✓ Saved JSON: crop_Componenets_1.transformed059.json
# ✓ Saved mask: crop_Componenets_1.transformed059.npy
# ✓ Saved JSON: crop_Componenets_1.transformed060.json
# ✓ Saved mask: crop_Componenets_1.transformed060.npy
# ✓ Saved JSON: crop_Componenets_1.transformed061.json
# ✓ Saved mask: crop_Componenets_1.transformed061.npy
# ✓ Saved JSON: crop_Componenets_1.transformed062.json
# ✓ Saved mask: crop_Componenets_1.transformed062.npy
# ✓ Saved JSON: crop_Componenets_1.transformed063.json
# ✓ Saved mask: crop_Componenets_1.transformed063.npy
# ✓ Saved JSON: crop_Componenets_1.transformed064.json
# ✓ Saved mask: crop_Componenets_1.transformed064.npy
# ✓ Saved JSON: crop_Componenets_1.transformed065.json
# ✓ Saved mask: crop_Componenets_1.transformed065.npy
# ✓ Saved JSON: crop_Componenets_1.transformed066.json
# ✓ Saved mask: crop_Componenets_1.transformed066.npy
# ✓ Saved JSON: crop_Componenets_1.transformed067.json
# ✓ Saved mask: crop_Componenets_1.transformed067.npy
# ✓ Saved JSON: crop_Componenets_1.transformed068.json
# ✓ Saved mask: crop_Componenets_1.transformed068.npy
# ✓ Saved JSON: crop_Componenets_1.transformed069.json
# ✓ Saved mask: crop_Componenets_1.transformed069.npy
# ✓ Saved JSON: crop_Componenets_1.transformed070.json
# ✓ Saved mask: crop_Componenets_1.transformed070.npy
# ✓ Saved JSON: crop_Componenets_1.transformed071.json
# ✓ Saved mask: crop_Componenets_1.transformed071.npy
# ✓ Saved JSON: crop_Componenets_1.transformed072.json
# ✓ Saved mask: crop_Componenets_1.transformed072.npy
# ✓ Saved JSON: crop_Componenets_1.transformed073.json
# ✓ Saved mask: crop_Componenets_1.transformed073.npy
# ✓ Saved JSON: crop_Componenets_1.transformed074.json
# ✓ Saved mask: crop_Componenets_1.transformed074.npy
# ✓ Saved JSON: crop_Componenets_1.transformed075.json
# ✓ Saved mask: crop_Componenets_1.transformed075.npy
# ✓ Saved JSON: crop_Componenets_1.transformed076.json
# ✓ Saved mask: crop_Componenets_1.transformed076.npy
# ✓ Saved JSON: crop_Componenets_1.transformed077.json
# ✓ Saved mask: crop_Componenets_1.transformed077.npy
# ✓ Saved JSON: crop_Componenets_1.transformed078.json
# ✓ Saved mask: crop_Componenets_1.transformed078.npy
# ✓ Saved JSON: crop_Componenets_1.transformed079.json
# ✓ Saved mask: crop_Componenets_1.transformed079.npy
# ✓ Saved JSON: crop_Componenets_1.transformed080.json
# ✓ Saved mask: crop_Componenets_1.transformed080.npy
# ✓ Saved JSON: crop_Componenets_1.transformed081.json
# ✓ Saved mask: crop_Componenets_1.transformed081.npy
# ✓ Saved JSON: crop_Componenets_1.transformed082.json
# ✓ Saved mask: crop_Componenets_1.transformed082.npy
# ✓ Saved JSON: crop_Componenets_1.transformed083.json
# ✓ Saved mask: crop_Componenets_1.transformed083.npy
# ✓ Saved JSON: crop_Componenets_1.transformed084.json
# ✓ Saved mask: crop_Componenets_1.transformed084.npy
# ✓ Saved JSON: crop_Componenets_1.transformed085.json
# ✓ Saved mask: crop_Componenets_1.transformed085.npy
# ✓ Saved JSON: crop_Componenets_1.transformed086.json
# ✓ Saved mask: crop_Componenets_1.transformed086.npy
# ✓ Saved JSON: crop_Componenets_1.transformed087.json
# ✓ Saved mask: crop_Componenets_1.transformed087.npy
# ✓ Saved JSON: crop_Componenets_1.transformed088.json
# ✓ Saved mask: crop_Componenets_1.transformed088.npy
# ✓ Saved JSON: crop_Componenets_1.transformed089.json
# ✓ Saved mask: crop_Componenets_1.transformed089.npy
# ✓ Saved JSON: crop_Componenets_1.transformed090.json
# ✓ Saved mask: crop_Componenets_1.transformed090.npy
# ✓ Saved JSON: crop_Componenets_1.transformed091.json
# ✓ Saved mask: crop_Componenets_1.transformed091.npy
# ✓ Saved JSON: crop_Componenets_1.transformed092.json
# ✓ Saved mask: crop_Componenets_1.transformed092.npy
# ✓ Saved JSON: crop_Componenets_1.transformed093.json
# ✓ Saved mask: crop_Componenets_1.transformed093.npy
# ✓ Saved JSON: crop_Componenets_1.transformed094.json
# ✓ Saved mask: crop_Componenets_1.transformed094.npy
# ✓ Saved JSON: crop_Componenets_1.transformed095.json
# ✓ Saved mask: crop_Componenets_1.transformed095.npy
# ✓ Saved JSON: crop_Componenets_1.transformed096.json
# ✓ Saved mask: crop_Componenets_1.transformed096.npy
# ✓ Saved JSON: crop_Componenets_1.transformed097.json
# ✓ Saved mask: crop_Componenets_1.transformed097.npy
# ✓ Saved JSON: crop_Componenets_1.transformed098.json
# ✓ Saved mask: crop_Componenets_1.transformed098.npy
# ✓ Saved JSON: crop_Componenets_1.transformed099.json
# ✓ Saved mask: crop_Componenets_1.transformed099.npy
# ✓ Saved JSON: crop_Componenets_1.transformed100.json
# ✓ Saved mask: crop_Componenets_1.transformed100.npy
# ✓ Saved JSON: crop_Componenets_1.transformed101.json
# ✓ Saved mask: crop_Componenets_1.transformed101.npy
# ✓ Saved JSON: crop_Componenets_1.transformed102.json
# ✓ Saved mask: crop_Componenets_1.transformed102.npy
# ✓ Saved JSON: crop_Componenets_1.transformed103.json
# ✓ Saved mask: crop_Componenets_1.transformed103.npy
# ✓ Saved JSON: crop_Componenets_1.transformed104.json
# ✓ Saved mask: crop_Componenets_1.transformed104.npy
# ✓ Saved JSON: crop_Componenets_1.transformed105.json
# ✓ Saved mask: crop_Componenets_1.transformed105.npy
# ✓ Saved JSON: crop_Componenets_1.transformed106.json
# ✓ Saved mask: crop_Componenets_1.transformed106.npy
# ✓ Saved JSON: crop_Componenets_1.transformed107.json
# ✓ Saved mask: crop_Componenets_1.transformed107.npy
# ✓ Saved JSON: crop_Componenets_1.transformed108.json
# ✓ Saved mask: crop_Componenets_1.transformed108.npy
# ✓ Saved JSON: crop_Componenets_1.transformed109.json
# ✓ Saved mask: crop_Componenets_1.transformed109.npy
# ✓ Saved JSON: crop_Componenets_1.transformed110.json
# ✓ Saved mask: crop_Componenets_1.transformed110.npy
# ✓ Saved JSON: crop_Componenets_1.transformed111.json
# ✓ Saved mask: crop_Componenets_1.transformed111.npy
# ✓ Saved JSON: crop_Componenets_1.transformed112.json
# ✓ Saved mask: crop_Componenets_1.transformed112.npy
# ✓ Saved JSON: crop_Componenets_1.transformed113.json
# ✓ Saved mask: crop_Componenets_1.transformed113.npy
# ✓ Saved JSON: crop_Componenets_1.transformed114.json
# ✓ Saved mask: crop_Componenets_1.transformed114.npy
# ✓ Saved JSON: crop_Componenets_1.transformed115.json
# ✓ Saved mask: crop_Componenets_1.transformed115.npy
# ✓ Saved JSON: crop_Componenets_1.transformed116.json
# ✓ Saved mask: crop_Componenets_1.transformed116.npy
# ✓ Saved JSON: crop_Componenets_1.transformed117.json
# ✓ Saved mask: crop_Componenets_1.transformed117.npy
# ✓ Saved JSON: crop_Componenets_1.transformed118.json
# ✓ Saved mask: crop_Componenets_1.transformed118.npy
# ✓ Saved JSON: crop_Componenets_1.transformed119.json
# ✓ Saved mask: crop_Componenets_1.transformed119.npy
# ✓ Saved JSON: crop_Componenets_1.transformed120.json
# ✓ Saved mask: crop_Componenets_1.transformed120.npy
# ✓ Saved JSON: crop_Componenets_1.transformed121.json
# ✓ Saved mask: crop_Componenets_1.transformed121.npy
# ✓ Saved JSON: crop_Componenets_1.transformed122.json
# ✓ Saved mask: crop_Componenets_1.transformed122.npy
# ✓ Saved JSON: crop_Componenets_1.transformed123.json
# ✓ Saved mask: crop_Componenets_1.transformed123.npy
# ✓ Saved JSON: crop_Componenets_1.transformed124.json
# ✓ Saved mask: crop_Componenets_1.transformed124.npy
# ✓ Saved JSON: crop_Componenets_1.transformed125.json
# ✓ Saved mask: crop_Componenets_1.transformed125.npy
# ✓ Saved JSON: crop_Componenets_1.transformed126.json
# ✓ Saved mask: crop_Componenets_1.transformed126.npy
# ✓ Saved JSON: crop_Componenets_1.transformed127.json
# ✓ Saved mask: crop_Componenets_1.transformed127.npy
# ✓ Saved JSON: crop_Componenets_1.transformed128.json
# ✓ Saved mask: crop_Componenets_1.transformed128.npy
# ✓ Saved JSON: crop_Componenets_1.transformed129.json
# ✓ Saved mask: crop_Componenets_1.transformed129.npy
# ✓ Saved JSON: crop_Componenets_1.transformed130.json
# ✓ Saved mask: crop_Componenets_1.transformed130.npy
# ✓ Saved JSON: crop_Componenets_1.transformed131.json
# ✓ Saved mask: crop_Componenets_1.transformed131.npy
# ✓ Saved JSON: crop_Componenets_1.transformed132.json
# ✓ Saved mask: crop_Componenets_1.transformed132.npy
# ✓ Saved JSON: crop_Componenets_1.transformed133.json
# ✓ Saved mask: crop_Componenets_1.transformed133.npy
# ✓ Saved JSON: crop_Componenets_1.transformed134.json
# ✓ Saved mask: crop_Componenets_1.transformed134.npy
# ✓ Saved JSON: crop_Componenets_1.transformed135.json
# ✓ Saved mask: crop_Componenets_1.transformed135.npy
# ✓ Saved JSON: crop_Componenets_1.transformed136.json
# ✓ Saved mask: crop_Componenets_1.transformed136.npy
# ✓ Saved JSON: crop_Componenets_1.transformed137.json
# ✓ Saved mask: crop_Componenets_1.transformed137.npy
# ✓ Saved JSON: crop_Componenets_1.transformed138.json
# ✓ Saved mask: crop_Componenets_1.transformed138.npy
# ✓ Saved JSON: crop_Componenets_1.transformed139.json
# ✓ Saved mask: crop_Componenets_1.transformed139.npy
# ✓ Saved JSON: crop_Componenets_1.transformed140.json
# ✓ Saved mask: crop_Componenets_1.transformed140.npy
# ✓ Saved JSON: crop_Componenets_1.transformed141.json
# ✓ Saved mask: crop_Componenets_1.transformed141.npy
# ✓ Saved JSON: crop_Componenets_1.transformed142.json
# ✓ Saved mask: crop_Componenets_1.transformed142.npy
# ✓ Saved JSON: crop_Componenets_1.transformed143.json
# ✓ Saved mask: crop_Componenets_1.transformed143.npy
# ✓ Saved JSON: crop_Componenets_1.transformed144.json
# ✓ Saved mask: crop_Componenets_1.transformed144.npy
# ✓ Saved JSON: crop_Componenets_1.transformed145.json
# ✓ Saved mask: crop_Componenets_1.transformed145.npy
# ✓ Saved JSON: crop_Componenets_1.transformed146.json
# ✓ Saved mask: crop_Componenets_1.transformed146.npy
# ✓ Saved JSON: crop_Componenets_1.transformed147.json
# ✓ Saved mask: crop_Componenets_1.transformed147.npy
# ✓ Saved JSON: crop_Componenets_1.transformed148.json
# ✓ Saved mask: crop_Componenets_1.transformed148.npy
# ✓ Saved JSON: crop_Componenets_1.transformed149.json
# ✓ Saved mask: crop_Componenets_1.transformed149.npy
# ✓ Saved JSON: crop_Componenets_1.transformed150.json
# ✓ Saved mask: crop_Componenets_1.transformed150.npy
# ✓ Saved JSON: crop_Componenets_1.transformed151.json
# ✓ Saved mask: crop_Componenets_1.transformed151.npy
# ✓ Saved JSON: crop_Componenets_1.transformed152.json
# ✓ Saved mask: crop_Componenets_1.transformed152.npy
# ✓ Saved JSON: crop_Componenets_1.transformed153.json
# ✓ Saved mask: crop_Componenets_1.transformed153.npy
# ✓ Saved JSON: crop_Componenets_1.transformed154.json
# ✓ Saved mask: crop_Componenets_1.transformed154.npy
# ✓ Saved JSON: crop_Componenets_1.transformed155.json
# ✓ Saved mask: crop_Componenets_1.transformed155.npy
# ✓ Saved JSON: crop_Componenets_1.transformed156.json
# ✓ Saved mask: crop_Componenets_1.transformed156.npy
# ✓ Saved JSON: crop_Componenets_1.transformed157.json
# ✓ Saved mask: crop_Componenets_1.transformed157.npy
# ✓ Saved JSON: crop_Componenets_1.transformed158.json
# ✓ Saved mask: crop_Componenets_1.transformed158.npy
# ✓ Saved JSON: crop_Componenets_1.transformed159.json
# ✓ Saved mask: crop_Componenets_1.transformed159.npy
# ✓ Saved JSON: crop_Componenets_1.transformed160.json
# ✓ Saved mask: crop_Componenets_1.transformed160.npy
# ✓ Saved JSON: crop_Componenets_1.transformed161.json
# ✓ Saved mask: crop_Componenets_1.transformed161.npy
# ✓ Saved JSON: crop_Componenets_1.transformed162.json
# ✓ Saved mask: crop_Componenets_1.transformed162.npy
# ✓ Saved JSON: crop_Componenets_1.transformed163.json
# ✓ Saved mask: crop_Componenets_1.transformed163.npy
# ✓ Saved JSON: crop_Componenets_1.transformed164.json
# ✓ Saved mask: crop_Componenets_1.transformed164.npy
# ✓ Saved JSON: crop_Componenets_1.transformed165.json
# ✓ Saved mask: crop_Componenets_1.transformed165.npy
# ✓ Saved JSON: crop_Componenets_1.transformed166.json
# ✓ Saved mask: crop_Componenets_1.transformed166.npy
# ✓ Saved JSON: crop_Componenets_1.transformed167.json
# ✓ Saved mask: crop_Componenets_1.transformed167.npy
# ✓ Saved JSON: crop_Componenets_1.transformed168.json
# ✓ Saved mask: crop_Componenets_1.transformed168.npy
# ✓ Saved JSON: crop_Componenets_1.transformed169.json
# ✓ Saved mask: crop_Componenets_1.transformed169.npy
# ✓ Saved JSON: crop_Componenets_1.transformed170.json
# ✓ Saved mask: crop_Componenets_1.transformed170.npy
# ✓ Saved JSON: crop_Componenets_1.transformed171.json
# ✓ Saved mask: crop_Componenets_1.transformed171.npy
# ✓ Saved JSON: crop_Componenets_1.transformed172.json
# ✓ Saved mask: crop_Componenets_1.transformed172.npy
# ✓ Saved JSON: crop_Componenets_1.transformed173.json
# ✓ Saved mask: crop_Componenets_1.transformed173.npy
# ✓ Saved JSON: crop_Componenets_1.transformed174.json
# ✓ Saved mask: crop_Componenets_1.transformed174.npy
# ✓ Saved JSON: crop_Componenets_1.transformed175.json
# ✓ Saved mask: crop_Componenets_1.transformed175.npy
# ✓ Saved JSON: crop_Componenets_1.transformed176.json
# ✓ Saved mask: crop_Componenets_1.transformed176.npy
# ✓ Saved JSON: crop_Componenets_1.transformed177.json
# ✓ Saved mask: crop_Componenets_1.transformed177.npy
# ✓ Saved JSON: crop_Componenets_1.transformed178.json
# ✓ Saved mask: crop_Componenets_1.transformed178.npy
# ✓ Saved JSON: crop_Componenets_1.transformed179.json
# ✓ Saved mask: crop_Componenets_1.transformed179.npy
# ✓ Saved JSON: crop_Componenets_1.transformed180.json
# ✓ Saved mask: crop_Componenets_1.transformed180.npy
# ✓ Saved JSON: crop_Componenets_1.transformed181.json
# ✓ Saved mask: crop_Componenets_1.transformed181.npy
# ✓ Saved JSON: crop_Componenets_1.transformed182.json
# ✓ Saved mask: crop_Componenets_1.transformed182.npy
# ✓ Saved JSON: crop_Componenets_1.transformed183.json
# ✓ Saved mask: crop_Componenets_1.transformed183.npy
# ✓ Saved JSON: crop_Componenets_1.transformed184.json
# ✓ Saved mask: crop_Componenets_1.transformed184.npy
# ✓ Saved JSON: crop_Componenets_1.transformed185.json
# ✓ Saved mask: crop_Componenets_1.transformed185.npy
# ✓ Saved JSON: crop_Componenets_1.transformed186.json
# ✓ Saved mask: crop_Componenets_1.transformed186.npy
# ✓ Saved JSON: crop_Componenets_1.transformed187.json
# ✓ Saved mask: crop_Componenets_1.transformed187.npy
# ✓ Saved JSON: crop_Componenets_1.transformed188.json
# ✓ Saved mask: crop_Componenets_1.transformed188.npy
# ✓ Saved JSON: crop_Componenets_1.transformed189.json
# ✓ Saved mask: crop_Componenets_1.transformed189.npy
# ✓ Saved JSON: crop_Componenets_1.transformed190.json
# ✓ Saved mask: crop_Componenets_1.transformed190.npy
# ✓ Saved JSON: crop_Componenets_1.transformed191.json
# ✓ Saved mask: crop_Componenets_1.transformed191.npy
# ✓ Saved JSON: crop_Componenets_1.transformed192.json
# ✓ Saved mask: crop_Componenets_1.transformed192.npy
# ✓ Saved JSON: crop_Componenets_1.transformed193.json
# ✓ Saved mask: crop_Componenets_1.transformed193.npy
# ✓ Saved JSON: crop_Componenets_1.transformed194.json
# ✓ Saved mask: crop_Componenets_1.transformed194.npy
# ✓ Saved JSON: crop_Componenets_1.transformed195.json
# ✓ Saved mask: crop_Componenets_1.transformed195.npy
# ✓ Saved JSON: crop_Componenets_1.transformed196.json
# ✓ Saved mask: crop_Componenets_1.transformed196.npy
# ✓ Saved JSON: crop_Componenets_1.transformed197.json
# ✓ Saved mask: crop_Componenets_1.transformed197.npy
# ✓ Saved JSON: crop_Componenets_1.transformed198.json
# ✓ Saved mask: crop_Componenets_1.transformed198.npy
# ✓ Saved JSON: crop_Componenets_1.transformed199.json
# ✓ Saved mask: crop_Componenets_1.transformed199.npy
# ✓ Saved JSON: crop_Componenets_1.transformed200.json
# ✓ Saved mask: crop_Componenets_1.transformed200.npy
# ✓ Saved JSON: crop_Componenets_1.transformed201.json
# ✓ Saved mask: crop_Componenets_1.transformed201.npy
# ✓ Saved JSON: crop_Componenets_1.transformed202.json
# ✓ Saved mask: crop_Componenets_1.transformed202.npy
# ✓ Saved JSON: crop_Componenets_1.transformed203.json
# ✓ Saved mask: crop_Componenets_1.transformed203.npy
# ✓ Saved JSON: crop_Componenets_1.transformed204.json
# ✓ Saved mask: crop_Componenets_1.transformed204.npy
# ✓ Saved JSON: crop_Componenets_1.transformed205.json
# ✓ Saved mask: crop_Componenets_1.transformed205.npy
# ✓ Saved JSON: crop_Componenets_1.transformed206.json
# ✓ Saved mask: crop_Componenets_1.transformed206.npy
# ✓ Saved JSON: crop_Componenets_1.transformed207.json
# ✓ Saved mask: crop_Componenets_1.transformed207.npy
# ✓ Saved JSON: crop_Componenets_1.transformed208.json
# ✓ Saved mask: crop_Componenets_1.transformed208.npy
# ✓ Saved JSON: crop_Componenets_1.transformed209.json
# ✓ Saved mask: crop_Componenets_1.transformed209.npy
# ✓ Saved JSON: crop_Componenets_1.transformed210.json
# ✓ Saved mask: crop_Componenets_1.transformed210.npy
# ✓ Saved JSON: crop_Componenets_1.transformed211.json
# ✓ Saved mask: crop_Componenets_1.transformed211.npy
# ✓ Saved JSON: crop_Componenets_1.transformed212.json
# ✓ Saved mask: crop_Componenets_1.transformed212.npy
# ✓ Saved JSON: crop_Componenets_1.transformed213.json
# ✓ Saved mask: crop_Componenets_1.transformed213.npy
# ✓ Saved JSON: crop_Componenets_1.transformed214.json
# ✓ Saved mask: crop_Componenets_1.transformed214.npy
# ✓ Saved JSON: crop_Componenets_1.transformed215.json
# ✓ Saved mask: crop_Componenets_1.transformed215.npy
# ✓ Saved JSON: crop_Componenets_1.transformed216.json
# ✓ Saved mask: crop_Componenets_1.transformed216.npy
# ✓ Saved JSON: crop_Componenets_1.transformed217.json
# ✓ Saved mask: crop_Componenets_1.transformed217.npy
# ✓ Saved JSON: crop_Componenets_1.transformed218.json
# ✓ Saved mask: crop_Componenets_1.transformed218.npy
# ✓ Saved JSON: crop_Componenets_1.transformed219.json
# ✓ Saved mask: crop_Componenets_1.transformed219.npy
# ✓ Saved JSON: crop_Componenets_1.transformed220.json
# ✓ Saved mask: crop_Componenets_1.transformed220.npy
# ✓ Saved JSON: crop_Componenets_1.transformed221.json
# ✓ Saved mask: crop_Componenets_1.transformed221.npy
# ✓ Saved JSON: crop_Componenets_1.transformed222.json
# ✓ Saved mask: crop_Componenets_1.transformed222.npy
# ✓ Saved JSON: crop_Componenets_1.transformed223.json
# ✓ Saved mask: crop_Componenets_1.transformed223.npy
# ✓ Saved JSON: crop_Componenets_1.transformed224.json
# ✓ Saved mask: crop_Componenets_1.transformed224.npy
# ✓ Saved JSON: crop_Componenets_1.transformed225.json
# ✓ Saved mask: crop_Componenets_1.transformed225.npy
# ✓ Saved JSON: crop_Componenets_1.transformed226.json
# ✓ Saved mask: crop_Componenets_1.transformed226.npy
# ✓ Saved JSON: crop_Componenets_1.transformed227.json
# ✓ Saved mask: crop_Componenets_1.transformed227.npy
# ✓ Saved JSON: crop_Componenets_1.transformed228.json
# ✓ Saved mask: crop_Componenets_1.transformed228.npy
# ✓ Saved JSON: crop_Componenets_1.transformed229.json
# ✓ Saved mask: crop_Componenets_1.transformed229.npy
# ✓ Saved JSON: crop_Componenets_1.transformed230.json
# ✓ Saved mask: crop_Componenets_1.transformed230.npy
# ✓ Saved JSON: crop_Componenets_1.transformed231.json
# ✓ Saved mask: crop_Componenets_1.transformed231.npy
# ✓ Saved JSON: crop_Componenets_1.transformed232.json
# ✓ Saved mask: crop_Componenets_1.transformed232.npy
# ✓ Saved JSON: crop_Componenets_1.transformed233.json
# ✓ Saved mask: crop_Componenets_1.transformed233.npy
# ✓ Saved JSON: crop_Componenets_1.transformed234.json
# ✓ Saved mask: crop_Componenets_1.transformed234.npy
# ✓ Saved JSON: crop_Componenets_1.transformed235.json
# ✓ Saved mask: crop_Componenets_1.transformed235.npy
# ✓ Saved JSON: crop_Componenets_1.transformed236.json
# ✓ Saved mask: crop_Componenets_1.transformed236.npy
# ✓ Saved JSON: crop_Componenets_1.transformed237.json
# ✓ Saved mask: crop_Componenets_1.transformed237.npy
# ✓ Saved JSON: crop_Componenets_1.transformed238.json
# ✓ Saved mask: crop_Componenets_1.transformed238.npy
# ✓ Saved JSON: crop_Componenets_1.transformed239.json
# ✓ Saved mask: crop_Componenets_1.transformed239.npy
# ✓ Saved JSON: crop_Componenets_1.transformed240.json
# ✓ Saved mask: crop_Componenets_1.transformed240.npy
# ✓ Saved JSON: crop_Componenets_1.transformed241.json
# ✓ Saved mask: crop_Componenets_1.transformed241.npy
# ✓ Saved JSON: crop_Componenets_1.transformed242.json
# ✓ Saved mask: crop_Componenets_1.transformed242.npy
# ✓ Saved JSON: crop_Componenets_1.transformed243.json
# ✓ Saved mask: crop_Componenets_1.transformed243.npy
# ✓ Saved JSON: crop_Componenets_1.transformed244.json
# ✓ Saved mask: crop_Componenets_1.transformed244.npy
# ✓ Saved JSON: crop_Componenets_1.transformed245.json
# ✓ Saved mask: crop_Componenets_1.transformed245.npy
# ✓ Saved JSON: crop_Componenets_1.transformed246.json
# ✓ Saved mask: crop_Componenets_1.transformed246.npy
# ✓ Saved JSON: crop_Componenets_1.transformed247.json
# ✓ Saved mask: crop_Componenets_1.transformed247.npy
# ✓ Saved JSON: crop_Componenets_1.transformed248.json
# ✓ Saved mask: crop_Componenets_1.transformed248.npy
# ✓ Saved JSON: crop_Componenets_1.transformed249.json
# ✓ Saved mask: crop_Componenets_1.transformed249.npy
# ✓ Saved JSON: crop_Componenets_1.transformed250.json
# ✓ Saved mask: crop_Componenets_1.transformed250.npy
# ✓ Saved JSON: crop_Componenets_1.transformed251.json
# ✓ Saved mask: crop_Componenets_1.transformed251.npy
# ✓ Saved JSON: crop_Componenets_1.transformed252.json
# ✓ Saved mask: crop_Componenets_1.transformed252.npy
# ✓ Saved JSON: crop_Componenets_1.transformed253.json
# ✓ Saved mask: crop_Componenets_1.transformed253.npy
# ✓ Saved JSON: crop_Componenets_1.transformed254.json
# ✓ Saved mask: crop_Componenets_1.transformed254.npy
# ✓ Saved JSON: crop_Componenets_1.transformed255.json
# ✓ Saved mask: crop_Componenets_1.transformed255.npy
# ✓ Saved JSON: crop_Componenets_1.transformed256.json
# ✓ Saved mask: crop_Componenets_1.transformed256.npy
# ✓ Saved JSON: crop_Componenets_1.transformed257.json
# ✓ Saved mask: crop_Componenets_1.transformed257.npy
# ✓ Saved JSON: crop_Componenets_1.transformed258.json
# ✓ Saved mask: crop_Componenets_1.transformed258.npy
# ✓ Saved JSON: crop_Componenets_1.transformed259.json
# ✓ Saved mask: crop_Componenets_1.transformed259.npy
# ✓ Saved JSON: crop_Componenets_1.transformed260.json
# ✓ Saved mask: crop_Componenets_1.transformed260.npy
# ✓ Saved JSON: crop_Componenets_1.transformed261.json
# ✓ Saved mask: crop_Componenets_1.transformed261.npy
# ✓ Saved JSON: crop_Componenets_1.transformed262.json
# ✓ Saved mask: crop_Componenets_1.transformed262.npy
# ✓ Saved JSON: crop_Componenets_1.transformed263.json
# ✓ Saved mask: crop_Componenets_1.transformed263.npy
# ✓ Saved JSON: crop_Componenets_1.transformed264.json
# ✓ Saved mask: crop_Componenets_1.transformed264.npy
# ✓ Saved JSON: crop_Componenets_1.transformed265.json
# ✓ Saved mask: crop_Componenets_1.transformed265.npy
# ✓ Saved JSON: crop_Componenets_1.transformed266.json
# ✓ Saved mask: crop_Componenets_1.transformed266.npy
# ✓ Saved JSON: crop_Componenets_1.transformed267.json
# ✓ Saved mask: crop_Componenets_1.transformed267.npy
# ✓ Saved JSON: crop_Componenets_1.transformed268.json
# ✓ Saved mask: crop_Componenets_1.transformed268.npy
# ✓ Saved JSON: crop_Componenets_1.transformed269.json
# ✓ Saved mask: crop_Componenets_1.transformed269.npy
# ✓ Saved JSON: crop_Componenets_1.transformed270.json
# ✓ Saved mask: crop_Componenets_1.transformed270.npy
# ✓ Saved JSON: crop_Componenets_1.transformed271.json
# ✓ Saved mask: crop_Componenets_1.transformed271.npy
# ✓ Saved JSON: crop_Componenets_1.transformed272.json
# ✓ Saved mask: crop_Componenets_1.transformed272.npy
# ✓ Saved JSON: crop_Componenets_1.transformed273.json
# ✓ Saved mask: crop_Componenets_1.transformed273.npy
# ✓ Saved JSON: crop_Componenets_1.transformed274.json
# ✓ Saved mask: crop_Componenets_1.transformed274.npy
# ✓ Saved JSON: crop_Componenets_1.transformed275.json
# ✓ Saved mask: crop_Componenets_1.transformed275.npy
# ✓ Saved JSON: crop_Componenets_1.transformed276.json
# ✓ Saved mask: crop_Componenets_1.transformed276.npy
# ✓ Saved JSON: crop_Componenets_1.transformed277.json
# ✓ Saved mask: crop_Componenets_1.transformed277.npy
# ✓ Saved JSON: crop_Componenets_1.transformed278.json
# ✓ Saved mask: crop_Componenets_1.transformed278.npy
# ✓ Saved JSON: crop_Componenets_1.transformed279.json
# ✓ Saved mask: crop_Componenets_1.transformed279.npy
# ✓ Saved JSON: crop_Componenets_1.transformed280.json
# ✓ Saved mask: crop_Componenets_1.transformed280.npy
# ✓ Saved JSON: crop_Componenets_1.transformed281.json
# ✓ Saved mask: crop_Componenets_1.transformed281.npy
# ✓ Saved JSON: crop_Componenets_1.transformed282.json
# ✓ Saved mask: crop_Componenets_1.transformed282.npy
# ✓ Saved JSON: crop_Componenets_1.transformed283.json
# ✓ Saved mask: crop_Componenets_1.transformed283.npy
# ✓ Saved JSON: crop_Componenets_1.transformed284.json
# ✓ Saved mask: crop_Componenets_1.transformed284.npy
# ✓ Saved JSON: crop_Componenets_1.transformed285.json
# ✓ Saved mask: crop_Componenets_1.transformed285.npy
# ✓ Saved JSON: crop_Componenets_1.transformed286.json
# ✓ Saved mask: crop_Componenets_1.transformed286.npy
# ✓ Saved JSON: crop_Componenets_1.transformed287.json
# ✓ Saved mask: crop_Componenets_1.transformed287.npy
# ✓ Saved JSON: crop_Componenets_1.transformed288.json
# ✓ Saved mask: crop_Componenets_1.transformed288.npy
# ✓ Saved JSON: crop_Componenets_1.transformed289.json
# ✓ Saved mask: crop_Componenets_1.transformed289.npy
# ✓ Saved JSON: crop_Componenets_1.transformed290.json
# ✓ Saved mask: crop_Componenets_1.transformed290.npy
# ✓ Saved JSON: crop_Componenets_1.transformed291.json
# ✓ Saved mask: crop_Componenets_1.transformed291.npy
# ✓ Saved JSON: crop_Componenets_1.transformed292.json
# ✓ Saved mask: crop_Componenets_1.transformed292.npy
# ✓ Saved JSON: crop_Componenets_1.transformed293.json
# ✓ Saved mask: crop_Componenets_1.transformed293.npy
# ✓ Saved JSON: crop_Componenets_1.transformed294.json
# ✓ Saved mask: crop_Componenets_1.transformed294.npy
# ✓ Saved JSON: crop_Componenets_1.transformed295.json
# ✓ Saved mask: crop_Componenets_1.transformed295.npy
# ✓ Saved JSON: crop_Componenets_1.transformed296.json
# ✓ Saved mask: crop_Componenets_1.transformed296.npy
# ✓ Saved JSON: crop_Componenets_1.transformed297.json
# ✓ Saved mask: crop_Componenets_1.transformed297.npy
# ✓ Saved JSON: crop_Componenets_1.transformed298.json
# ✓ Saved mask: crop_Componenets_1.transformed298.npy
# ✓ Saved JSON: crop_Componenets_1.transformed299.json
# ✓ Saved mask: crop_Componenets_1.transformed299.npy
# ✓ Saved JSON: crop_Componenets_1.transformed300.json
# ✓ Saved mask: crop_Componenets_1.transformed300.npy
# ✓ Saved JSON: crop_Componenets_1.transformed301.json
# ✓ Saved mask: crop_Componenets_1.transformed301.npy
# ✓ Saved JSON: crop_Componenets_1.transformed302.json
# ✓ Saved mask: crop_Componenets_1.transformed302.npy
# ✓ Saved JSON: crop_Componenets_1.transformed303.json
# ✓ Saved mask: crop_Componenets_1.transformed303.npy
# ✓ Saved JSON: crop_Componenets_1.transformed304.json
# ✓ Saved mask: crop_Componenets_1.transformed304.npy
# ✓ Saved JSON: crop_Componenets_1.transformed305.json
# ✓ Saved mask: crop_Componenets_1.transformed305.npy
# ✓ Saved JSON: crop_Componenets_1.transformed306.json
# ✓ Saved mask: crop_Componenets_1.transformed306.npy
# ✓ Saved JSON: crop_Componenets_1.transformed307.json
# ✓ Saved mask: crop_Componenets_1.transformed307.npy
# ✓ Saved JSON: crop_Componenets_1.transformed308.json
# ✓ Saved mask: crop_Componenets_1.transformed308.npy
# ✓ Saved JSON: crop_Componenets_1.transformed309.json
# ✓ Saved mask: crop_Componenets_1.transformed309.npy
# ✓ Saved JSON: crop_Componenets_1.transformed310.json
# ✓ Saved mask: crop_Componenets_1.transformed310.npy
# ✓ Saved JSON: crop_Componenets_1.transformed311.json
# ✓ Saved mask: crop_Componenets_1.transformed311.npy
# ✓ Saved JSON: crop_Componenets_1.transformed312.json
# ✓ Saved mask: crop_Componenets_1.transformed312.npy
# ✓ Saved JSON: crop_Componenets_1.transformed313.json
# ✓ Saved mask: crop_Componenets_1.transformed313.npy
# ✓ Saved JSON: crop_Componenets_1.transformed314.json
# ✓ Saved mask: crop_Componenets_1.transformed314.npy
# ✓ Saved JSON: crop_Componenets_1.transformed315.json
# ✓ Saved mask: crop_Componenets_1.transformed315.npy
# ✓ Saved JSON: crop_Componenets_1.transformed316.json
# ✓ Saved mask: crop_Componenets_1.transformed316.npy
# ✓ Saved JSON: crop_Componenets_1.transformed317.json
# ✓ Saved mask: crop_Componenets_1.transformed317.npy
# ✓ Saved JSON: crop_Componenets_1.transformed318.json
# ✓ Saved mask: crop_Componenets_1.transformed318.npy
# ✓ Saved JSON: crop_Componenets_1.transformed319.json
# ✓ Saved mask: crop_Componenets_1.transformed319.npy
# ✓ Saved JSON: crop_Componenets_1.transformed320.json
# ✓ Saved mask: crop_Componenets_1.transformed320.npy
# ✓ Saved JSON: crop_Componenets_1.transformed321.json
# ✓ Saved mask: crop_Componenets_1.transformed321.npy
# ✓ Saved JSON: crop_Componenets_1.transformed322.json
# ✓ Saved mask: crop_Componenets_1.transformed322.npy
# ✓ Saved JSON: crop_Componenets_1.transformed323.json
# ✓ Saved mask: crop_Componenets_1.transformed323.npy
# ✓ Saved JSON: crop_Componenets_1.transformed324.json
# ✓ Saved mask: crop_Componenets_1.transformed324.npy
# ✓ Saved JSON: crop_Componenets_1.transformed325.json
# ✓ Saved mask: crop_Componenets_1.transformed325.npy
# ✓ Saved JSON: crop_Componenets_1.transformed326.json
# ✓ Saved mask: crop_Componenets_1.transformed326.npy
# ✓ Saved JSON: crop_Componenets_1.transformed327.json
# ✓ Saved mask: crop_Componenets_1.transformed327.npy
# ✓ Saved JSON: crop_Componenets_1.transformed328.json
# ✓ Saved mask: crop_Componenets_1.transformed328.npy
# ✓ Saved JSON: crop_Componenets_1.transformed329.json
# ✓ Saved mask: crop_Componenets_1.transformed329.npy
# ✓ Saved JSON: crop_Componenets_1.transformed330.json
# ✓ Saved mask: crop_Componenets_1.transformed330.npy
# ✓ Saved JSON: crop_Componenets_1.transformed331.json
# ✓ Saved mask: crop_Componenets_1.transformed331.npy
# ✓ Saved JSON: crop_Componenets_1.transformed332.json
# ✓ Saved mask: crop_Componenets_1.transformed332.npy
# ✓ Saved JSON: crop_Componenets_1.transformed333.json
# ✓ Saved mask: crop_Componenets_1.transformed333.npy
# ✓ Saved JSON: crop_Componenets_1.transformed334.json
# ✓ Saved mask: crop_Componenets_1.transformed334.npy
# ✓ Saved JSON: crop_Componenets_1.transformed335.json
# ✓ Saved mask: crop_Componenets_1.transformed335.npy
# ✓ Saved JSON: crop_Componenets_1.transformed336.json
# ✓ Saved mask: crop_Componenets_1.transformed336.npy
# ✓ Saved JSON: crop_Componenets_1.transformed337.json
# ✓ Saved mask: crop_Componenets_1.transformed337.npy
# ✓ Saved JSON: crop_Componenets_1.transformed338.json
# ✓ Saved mask: crop_Componenets_1.transformed338.npy
# ✓ Saved JSON: crop_Componenets_1.transformed339.json
# ✓ Saved mask: crop_Componenets_1.transformed339.npy
# ✓ Saved JSON: crop_Componenets_1.transformed340.json
# ✓ Saved mask: crop_Componenets_1.transformed340.npy
# ✓ Saved JSON: crop_Componenets_1.transformed341.json
# ✓ Saved mask: crop_Componenets_1.transformed341.npy
# ✓ Saved JSON: crop_Componenets_1.transformed342.json
# ✓ Saved mask: crop_Componenets_1.transformed342.npy
# ✓ Saved JSON: crop_Componenets_1.transformed343.json
# ✓ Saved mask: crop_Componenets_1.transformed343.npy
# ✓ Saved JSON: crop_Componenets_1.transformed344.json
# ✓ Saved mask: crop_Componenets_1.transformed344.npy
# ✓ Saved JSON: crop_Componenets_1.transformed345.json
# ✓ Saved mask: crop_Componenets_1.transformed345.npy
# ✓ Saved JSON: crop_Componenets_1.transformed346.json
# ✓ Saved mask: crop_Componenets_1.transformed346.npy
# ✓ Saved JSON: crop_Componenets_1.transformed347.json
# ✓ Saved mask: crop_Componenets_1.transformed347.npy
# ✓ Saved JSON: crop_Componenets_1.transformed348.json
# ✓ Saved mask: crop_Componenets_1.transformed348.npy
# ✓ Saved JSON: crop_Componenets_1.transformed349.json
# ✓ Saved mask: crop_Componenets_1.transformed349.npy
# ✓ Saved JSON: crop_Componenets_1.transformed350.json
# ✓ Saved mask: crop_Componenets_1.transformed350.npy
# ✓ Saved JSON: crop_Componenets_1.transformed351.json
# ✓ Saved mask: crop_Componenets_1.transformed351.npy
# ✓ Saved JSON: crop_Componenets_1.transformed352.json
# ✓ Saved mask: crop_Componenets_1.transformed352.npy
# ✓ Saved JSON: crop_Componenets_1.transformed353.json
# ✓ Saved mask: crop_Componenets_1.transformed353.npy
# ✓ Saved JSON: crop_Componenets_1.transformed354.json
# ✓ Saved mask: crop_Componenets_1.transformed354.npy
# ✓ Saved JSON: crop_Componenets_1.transformed355.json
# ✓ Saved mask: crop_Componenets_1.transformed355.npy
# ✓ Saved JSON: crop_Componenets_1.transformed356.json
# ✓ Saved mask: crop_Componenets_1.transformed356.npy
# ✓ Saved JSON: crop_Componenets_1.transformed357.json
# ✓ Saved mask: crop_Componenets_1.transformed357.npy
# ✓ Saved JSON: crop_Componenets_1.transformed358.json
# ✓ Saved mask: crop_Componenets_1.transformed358.npy
# ✓ Saved JSON: crop_Componenets_1.transformed359.json
# ✓ Saved mask: crop_Componenets_1.transformed359.npy
# ✓ Saved JSON: crop_Componenets_1.transformed360.json
# ✓ Saved mask: crop_Componenets_1.transformed360.npy
# ✓ Saved JSON: crop_Componenets_1.transformed361.json
# ✓ Saved mask: crop_Componenets_1.transformed361.npy
# ✓ Saved JSON: crop_Componenets_1.transformed362.json
# ✓ Saved mask: crop_Componenets_1.transformed362.npy
# ✓ Saved JSON: crop_Componenets_1.transformed363.json
# ✓ Saved mask: crop_Componenets_1.transformed363.npy
# ✓ Saved JSON: crop_Componenets_1.transformed364.json
# ✓ Saved mask: crop_Componenets_1.transformed364.npy
# ✓ Saved JSON: crop_Componenets_1.transformed365.json
# ✓ Saved mask: crop_Componenets_1.transformed365.npy
# ✓ Saved JSON: crop_Componenets_1.transformed366.json
# ✓ Saved mask: crop_Componenets_1.transformed366.npy
# ✓ Saved JSON: crop_Componenets_1.transformed367.json
# ✓ Saved mask: crop_Componenets_1.transformed367.npy
# ✓ Saved JSON: crop_Componenets_1.transformed368.json
# ✓ Saved mask: crop_Componenets_1.transformed368.npy
# ✓ Saved JSON: crop_Componenets_1.transformed369.json
# ✓ Saved mask: crop_Componenets_1.transformed369.npy
# ✓ Saved JSON: crop_Componenets_1.transformed370.json
# ✓ Saved mask: crop_Componenets_1.transformed370.npy
# ✓ Saved JSON: crop_Componenets_1.transformed371.json
# ✓ Saved mask: crop_Componenets_1.transformed371.npy
# ✓ Saved JSON: crop_Componenets_1.transformed372.json
# ✓ Saved mask: crop_Componenets_1.transformed372.npy
# ✓ Saved JSON: crop_Componenets_1.transformed373.json
# ✓ Saved mask: crop_Componenets_1.transformed373.npy
# ✓ Saved JSON: crop_Componenets_1.transformed374.json
# ✓ Saved mask: crop_Componenets_1.transformed374.npy
# ✓ Saved JSON: crop_Componenets_1.transformed375.json
# ✓ Saved mask: crop_Componenets_1.transformed375.npy
# ✓ Saved JSON: crop_Componenets_1.transformed376.json
# ✓ Saved mask: crop_Componenets_1.transformed376.npy
# ✓ Saved JSON: crop_Componenets_1.transformed377.json
# ✓ Saved mask: crop_Componenets_1.transformed377.npy
# ✓ Saved JSON: crop_Componenets_1.transformed378.json
# ✓ Saved mask: crop_Componenets_1.transformed378.npy
# ✓ Saved JSON: crop_Componenets_1.transformed379.json
# ✓ Saved mask: crop_Componenets_1.transformed379.npy
# ✓ Saved JSON: crop_Componenets_1.transformed380.json
# ✓ Saved mask: crop_Componenets_1.transformed380.npy
# ✓ Saved JSON: crop_Componenets_1.transformed381.json
# ✓ Saved mask: crop_Componenets_1.transformed381.npy
# ✓ Saved JSON: crop_Componenets_1.transformed382.json
# ✓ Saved mask: crop_Componenets_1.transformed382.npy
# ✓ Saved JSON: crop_Componenets_1.transformed383.json
# ✓ Saved mask: crop_Componenets_1.transformed383.npy
# ✓ Saved JSON: crop_Componenets_1.transformed384.json
# ✓ Saved mask: crop_Componenets_1.transformed384.npy
# ✓ Saved JSON: crop_Componenets_1.transformed385.json
# ✓ Saved mask: crop_Componenets_1.transformed385.npy
# ✓ Saved JSON: crop_Componenets_1.transformed386.json
# ✓ Saved mask: crop_Componenets_1.transformed386.npy
# ✓ Saved JSON: crop_Componenets_1.transformed387.json
# ✓ Saved mask: crop_Componenets_1.transformed387.npy
# ✓ Saved JSON: crop_Componenets_1.transformed388.json
# ✓ Saved mask: crop_Componenets_1.transformed388.npy
# ✓ Saved JSON: crop_Componenets_1.transformed389.json
# ✓ Saved mask: crop_Componenets_1.transformed389.npy
# ✓ Saved JSON: crop_Componenets_1.transformed390.json
# ✓ Saved mask: crop_Componenets_1.transformed390.npy
# ✓ Saved JSON: crop_Componenets_1.transformed391.json
# ✓ Saved mask: crop_Componenets_1.transformed391.npy
# ✓ Saved JSON: crop_Componenets_1.transformed392.json
# ✓ Saved mask: crop_Componenets_1.transformed392.npy
# ✓ Saved JSON: crop_Componenets_1.transformed393.json
# ✓ Saved mask: crop_Componenets_1.transformed393.npy
# ✓ Saved JSON: crop_Componenets_1.transformed394.json
# ✓ Saved mask: crop_Componenets_1.transformed394.npy
# ✓ Saved JSON: crop_Componenets_1.transformed395.json
# ✓ Saved mask: crop_Componenets_1.transformed395.npy
# ✓ Saved JSON: crop_Componenets_1.transformed396.json
# ✓ Saved mask: crop_Componenets_1.transformed396.npy
# ✓ Saved JSON: crop_Componenets_1.transformed397.json
# ✓ Saved mask: crop_Componenets_1.transformed397.npy
# ✓ Saved JSON: crop_Componenets_1.transformed398.json
# ✓ Saved mask: crop_Componenets_1.transformed398.npy
# ✓ Saved JSON: crop_Componenets_1.transformed399.json
# ✓ Saved mask: crop_Componenets_1.transformed399.npy
# ✓ Saved JSON: crop_Componenets_1.transformed400.json
# ✓ Saved mask: crop_Componenets_1.transformed400.npy
# ✓ Saved JSON: crop_Componenets_1.transformed401.json
# ✓ Saved mask: crop_Componenets_1.transformed401.npy
# ✓ Saved JSON: crop_Componenets_1.transformed402.json
# ✓ Saved mask: crop_Componenets_1.transformed402.npy
# ✓ Saved JSON: crop_Componenets_1.transformed403.json
# ✓ Saved mask: crop_Componenets_1.transformed403.npy
# ✓ Saved JSON: crop_Componenets_1.transformed404.json
# ✓ Saved mask: crop_Componenets_1.transformed404.npy
# ✓ Saved JSON: crop_Componenets_1.transformed405.json
# ✓ Saved mask: crop_Componenets_1.transformed405.npy
# ✓ Saved JSON: crop_Componenets_1.transformed406.json
# ✓ Saved mask: crop_Componenets_1.transformed406.npy
# ✓ Saved JSON: crop_Componenets_1.transformed407.json
# ✓ Saved mask: crop_Componenets_1.transformed407.npy
# ✓ Saved JSON: crop_Componenets_1.transformed408.json
# ✓ Saved mask: crop_Componenets_1.transformed408.npy
# ✓ Saved JSON: crop_Componenets_1.transformed409.json
# ✓ Saved mask: crop_Componenets_1.transformed409.npy
# ✓ Saved JSON: crop_Componenets_1.transformed410.json
# ✓ Saved mask: crop_Componenets_1.transformed410.npy
# ✓ Saved JSON: crop_Componenets_1.transformed411.json
# ✓ Saved mask: crop_Componenets_1.transformed411.npy
# ✓ Saved JSON: crop_Componenets_1.transformed412.json
# ✓ Saved mask: crop_Componenets_1.transformed412.npy
# ✓ Saved JSON: crop_Componenets_1.transformed413.json
# ✓ Saved mask: crop_Componenets_1.transformed413.npy
# ✓ Saved JSON: crop_Componenets_1.transformed414.json
# ✓ Saved mask: crop_Componenets_1.transformed414.npy
# ✓ Saved JSON: crop_Componenets_1.transformed415.json
# ✓ Saved mask: crop_Componenets_1.transformed415.npy
# ✓ Saved JSON: crop_Componenets_1.transformed416.json
# ✓ Saved mask: crop_Componenets_1.transformed416.npy
# ✓ Saved JSON: crop_Componenets_1.transformed417.json
# ✓ Saved mask: crop_Componenets_1.transformed417.npy
# ✓ Saved JSON: crop_Componenets_1.transformed418.json
# ✓ Saved mask: crop_Componenets_1.transformed418.npy
# ✓ Saved JSON: crop_Componenets_1.transformed419.json
# ✓ Saved mask: crop_Componenets_1.transformed419.npy
# ✓ Saved JSON: crop_Componenets_1.transformed420.json
# ✓ Saved mask: crop_Componenets_1.transformed420.npy
# ✓ Saved JSON: crop_Componenets_1.transformed421.json
# ✓ Saved mask: crop_Componenets_1.transformed421.npy
# ✓ Saved JSON: crop_Componenets_1.transformed422.json
# ✓ Saved mask: crop_Componenets_1.transformed422.npy
# ✓ Saved JSON: crop_Componenets_1.transformed423.json
# ✓ Saved mask: crop_Componenets_1.transformed423.npy
# ✓ Saved JSON: crop_Componenets_1.transformed424.json
# ✓ Saved mask: crop_Componenets_1.transformed424.npy
# ✓ Saved JSON: crop_Componenets_1.transformed425.json
# ✓ Saved mask: crop_Componenets_1.transformed425.npy
# ✓ Saved JSON: crop_Componenets_1.transformed426.json
# ✓ Saved mask: crop_Componenets_1.transformed426.npy
# ✓ Saved JSON: crop_Componenets_1.transformed427.json
# ✓ Saved mask: crop_Componenets_1.transformed427.npy
# ✓ Saved JSON: crop_Componenets_1.transformed428.json
# ✓ Saved mask: crop_Componenets_1.transformed428.npy
# ✓ Saved JSON: crop_Componenets_1.transformed429.json
# ✓ Saved mask: crop_Componenets_1.transformed429.npy
# ✓ Saved JSON: crop_Componenets_1.transformed430.json
# ✓ Saved mask: crop_Componenets_1.transformed430.npy
# ✓ Saved JSON: crop_Componenets_1.transformed431.json
# ✓ Saved mask: crop_Componenets_1.transformed431.npy
# ✓ Saved JSON: crop_Componenets_1.transformed432.json
# ✓ Saved mask: crop_Componenets_1.transformed432.npy
# ✓ Saved JSON: crop_Componenets_1.transformed433.json
# ✓ Saved mask: crop_Componenets_1.transformed433.npy
# ✓ Saved JSON: crop_Componenets_1.transformed434.json
# ✓ Saved mask: crop_Componenets_1.transformed434.npy
# ✓ Saved JSON: crop_Componenets_1.transformed435.json
# ✓ Saved mask: crop_Componenets_1.transformed435.npy
# ✓ Saved JSON: crop_Componenets_1.transformed436.json
# ✓ Saved mask: crop_Componenets_1.transformed436.npy
# ✓ Saved JSON: crop_Componenets_1.transformed437.json
# ✓ Saved mask: crop_Componenets_1.transformed437.npy
# ✓ Saved JSON: crop_Componenets_1.transformed438.json
# ✓ Saved mask: crop_Componenets_1.transformed438.npy
# ✓ Saved JSON: crop_Componenets_1.transformed439.json
# ✓ Saved mask: crop_Componenets_1.transformed439.npy
# ✓ Saved JSON: crop_Componenets_1.transformed440.json
# ✓ Saved mask: crop_Componenets_1.transformed440.npy
# ✓ Saved JSON: crop_Componenets_1.transformed441.json
# ✓ Saved mask: crop_Componenets_1.transformed441.npy
# ✓ Saved JSON: crop_Componenets_1.transformed442.json
# ✓ Saved mask: crop_Componenets_1.transformed442.npy
# ✓ Saved JSON: crop_Componenets_1.transformed443.json
# ✓ Saved mask: crop_Componenets_1.transformed443.npy
# ✓ Saved JSON: crop_Componenets_1.transformed444.json
# ✓ Saved mask: crop_Componenets_1.transformed444.npy
# ✓ Saved JSON: crop_Componenets_1.transformed445.json
# ✓ Saved mask: crop_Componenets_1.transformed445.npy
# ✓ Saved JSON: crop_Componenets_1.transformed446.json
# ✓ Saved mask: crop_Componenets_1.transformed446.npy
# ✓ Saved JSON: crop_Componenets_1.transformed447.json
# ✓ Saved mask: crop_Componenets_1.transformed447.npy
# ✓ Saved JSON: crop_Componenets_1.transformed448.json
# ✓ Saved mask: crop_Componenets_1.transformed448.npy
# ✓ Saved JSON: crop_Componenets_1.transformed449.json
# ✓ Saved mask: crop_Componenets_1.transformed449.npy
# ✓ Saved JSON: crop_Componenets_1.transformed450.json
# ✓ Saved mask: crop_Componenets_1.transformed450.npy
# ✓ Saved JSON: crop_Componenets_1.transformed451.json
# ✓ Saved mask: crop_Componenets_1.transformed451.npy
# ✓ Saved JSON: crop_Componenets_1.transformed452.json
# ✓ Saved mask: crop_Componenets_1.transformed452.npy
# ✓ Saved JSON: crop_Componenets_1.transformed453.json
# ✓ Saved mask: crop_Componenets_1.transformed453.npy
# ✓ Saved JSON: crop_Componenets_1.transformed454.json
# ✓ Saved mask: crop_Componenets_1.transformed454.npy
# ✓ Saved JSON: crop_Componenets_1.transformed455.json
# ✓ Saved mask: crop_Componenets_1.transformed455.npy
# ✓ Saved JSON: crop_Componenets_1.transformed456.json
# ✓ Saved mask: crop_Componenets_1.transformed456.npy
# ✓ Saved JSON: crop_Componenets_1.transformed457.json
# ✓ Saved mask: crop_Componenets_1.transformed457.npy
# ✓ Saved JSON: crop_Componenets_1.transformed458.json
# ✓ Saved mask: crop_Componenets_1.transformed458.npy
# ✓ Saved JSON: crop_Componenets_1.transformed459.json
# ✓ Saved mask: crop_Componenets_1.transformed459.npy
# ✓ Saved JSON: crop_Componenets_1.transformed460.json
# ✓ Saved mask: crop_Componenets_1.transformed460.npy
# ✓ Saved JSON: crop_Componenets_1.transformed461.json
# ✓ Saved mask: crop_Componenets_1.transformed461.npy
# ✓ Saved JSON: crop_Componenets_1.transformed462.json
# ✓ Saved mask: crop_Componenets_1.transformed462.npy
# ✓ Saved JSON: crop_Componenets_1.transformed463.json
# ✓ Saved mask: crop_Componenets_1.transformed463.npy
# ✓ Saved JSON: crop_Componenets_1.transformed464.json
# ✓ Saved mask: crop_Componenets_1.transformed464.npy
# ✓ Saved JSON: crop_Componenets_1.transformed465.json
# ✓ Saved mask: crop_Componenets_1.transformed465.npy
# ✓ Saved JSON: crop_Componenets_1.transformed466.json
# ✓ Saved mask: crop_Componenets_1.transformed466.npy
# ✓ Saved JSON: crop_Componenets_1.transformed467.json
# ✓ Saved mask: crop_Componenets_1.transformed467.npy
# ✓ Saved JSON: crop_Componenets_1.transformed468.json
# ✓ Saved mask: crop_Componenets_1.transformed468.npy
# ✓ Saved JSON: crop_Componenets_1.transformed469.json
# ✓ Saved mask: crop_Componenets_1.transformed469.npy
# ✓ Saved JSON: crop_Componenets_1.transformed470.json
# ✓ Saved mask: crop_Componenets_1.transformed470.npy
# ✓ Saved JSON: crop_Componenets_1.transformed471.json
# ✓ Saved mask: crop_Componenets_1.transformed471.npy
# ✓ Saved JSON: crop_Componenets_1.transformed472.json
# ✓ Saved mask: crop_Componenets_1.transformed472.npy
# ✓ Saved JSON: crop_Componenets_1.transformed473.json
# ✓ Saved mask: crop_Componenets_1.transformed473.npy
# ✓ Saved JSON: crop_Componenets_1.transformed474.json
# ✓ Saved mask: crop_Componenets_1.transformed474.npy
# ✓ Saved JSON: crop_Componenets_1.transformed475.json
# ✓ Saved mask: crop_Componenets_1.transformed475.npy
# ✓ Saved JSON: crop_Componenets_1.transformed476.json
# ✓ Saved mask: crop_Componenets_1.transformed476.npy
# ✓ Saved JSON: crop_Componenets_1.transformed477.json
# ✓ Saved mask: crop_Componenets_1.transformed477.npy
# ✓ Saved JSON: crop_Componenets_1.transformed478.json
# ✓ Saved mask: crop_Componenets_1.transformed478.npy
# ✓ Saved JSON: crop_Componenets_1.transformed479.json
# ✓ Saved mask: crop_Componenets_1.transformed479.npy
# ✓ Saved JSON: crop_Componenets_1.transformed480.json
# ✓ Saved mask: crop_Componenets_1.transformed480.npy
# ✓ Saved JSON: crop_Componenets_1.transformed481.json
# ✓ Saved mask: crop_Componenets_1.transformed481.npy
# ✓ Saved JSON: crop_Componenets_1.transformed482.json
# ✓ Saved mask: crop_Componenets_1.transformed482.npy
# ✓ Saved JSON: crop_Componenets_1.transformed483.json
# ✓ Saved mask: crop_Componenets_1.transformed483.npy
# ✓ Saved JSON: crop_Componenets_1.transformed484.json
# ✓ Saved mask: crop_Componenets_1.transformed484.npy
# ✓ Saved JSON: crop_Componenets_1.transformed485.json
# ✓ Saved mask: crop_Componenets_1.transformed485.npy
# ✓ Saved JSON: crop_Componenets_1.transformed486.json
# ✓ Saved mask: crop_Componenets_1.transformed486.npy
# ✓ Saved JSON: crop_Componenets_1.transformed487.json
# ✓ Saved mask: crop_Componenets_1.transformed487.npy
# ✓ Saved JSON: crop_Componenets_1.transformed488.json
# ✓ Saved mask: crop_Componenets_1.transformed488.npy
# ✓ Saved JSON: crop_Componenets_1.transformed489.json
# ✓ Saved mask: crop_Componenets_1.transformed489.npy
# ✓ Saved JSON: crop_Componenets_1.transformed490.json
# ✓ Saved mask: crop_Componenets_1.transformed490.npy
# ✓ Saved JSON: crop_Componenets_1.transformed491.json
# ✓ Saved mask: crop_Componenets_1.transformed491.npy
# ✓ Saved JSON: crop_Componenets_1.transformed492.json
# ✓ Saved mask: crop_Componenets_1.transformed492.npy
# ✓ Saved JSON: crop_Componenets_1.transformed493.json
# ✓ Saved mask: crop_Componenets_1.transformed493.npy
# ✓ Saved JSON: crop_Componenets_1.transformed494.json
# ✓ Saved mask: crop_Componenets_1.transformed494.npy
# ✓ Saved JSON: crop_Componenets_1.transformed495.json
# ✓ Saved mask: crop_Componenets_1.transformed495.npy
# ✓ Saved JSON: crop_Componenets_1.transformed496.json
# ✓ Saved mask: crop_Componenets_1.transformed496.npy
# ✓ Saved JSON: crop_Componenets_1.transformed497.json
# ✓ Saved mask: crop_Componenets_1.transformed497.npy
# ✓ Saved JSON: crop_Componenets_1.transformed498.json
# ✓ Saved mask: crop_Componenets_1.transformed498.npy
# ✓ Saved JSON: crop_Componenets_1.transformed499.json
# ✓ Saved mask: crop_Componenets_1.transformed499.npy
# ✓ Saved JSON: crop_Componenets_1.transformed500.json
# ✓ Saved mask: crop_Componenets_1.transformed500.npy
# ✓ Saved JSON: crop_Componenets_1.transformed501.json
# ✓ Saved mask: crop_Componenets_1.transformed501.npy
# ✓ Saved JSON: crop_Componenets_1.transformed502.json
# ✓ Saved mask: crop_Componenets_1.transformed502.npy
# ✓ Saved JSON: crop_Componenets_1.transformed503.json
# ✓ Saved mask: crop_Componenets_1.transformed503.npy
# ✓ Saved JSON: crop_Componenets_1.transformed504.json
# ✓ Saved mask: crop_Componenets_1.transformed504.npy
# ✓ Saved JSON: crop_Componenets_1.transformed505.json
# ✓ Saved mask: crop_Componenets_1.transformed505.npy
# ✓ Saved JSON: crop_Componenets_1.transformed506.json
# ✓ Saved mask: crop_Componenets_1.transformed506.npy
# ✓ Saved JSON: crop_Componenets_1.transformed507.json
# ✓ Saved mask: crop_Componenets_1.transformed507.npy
# ✓ Saved JSON: crop_Componenets_1.transformed508.json
# ✓ Saved mask: crop_Componenets_1.transformed508.npy
# ✓ Saved JSON: crop_Componenets_1.transformed509.json
# ✓ Saved mask: crop_Componenets_1.transformed509.npy
# ✓ Saved JSON: crop_Componenets_1.transformed510.json
# ✓ Saved mask: crop_Componenets_1.transformed510.npy
# ✓ Saved JSON: crop_Componenets_1.transformed511.json
# ✓ Saved mask: crop_Componenets_1.transformed511.npy
# ✓ Saved JSON: crop_Componenets_1.transformed512.json
# ✓ Saved mask: crop_Componenets_1.transformed512.npy
# ✓ Saved JSON: crop_Componenets_1.transformed513.json
# ✓ Saved mask: crop_Componenets_1.transformed513.npy
# ✓ Saved JSON: crop_Componenets_1.transformed514.json
# ✓ Saved mask: crop_Componenets_1.transformed514.npy
# ✓ Saved JSON: crop_Componenets_1.transformed515.json
# ✓ Saved mask: crop_Componenets_1.transformed515.npy
# ...
# ✓ Saved JSON: crop_Componenets_1.transformed739.json
# ✓ Saved mask: crop_Componenets_1.transformed739.npy
# ✓ Saved JSON: crop_Componenets_1.transformed740.json
# ✓ Saved mask: crop_Componenets_1.transformed740.npy
# ✓ Saved JSON: crop_Componenets_1.transformed741.json
# ✓ Saved mask: crop_Componenets_1.transformed741.npy
# ✓ Saved JSON: crop_Componenets_1.transformed742.json
# ✓ Saved mask: crop_Componenets_1.transformed742.npy
# ✓ Saved JSON: crop_Componenets_1.transformed743.json
# ✓ Saved mask: crop_Componenets_1.transformed743.npy
# ✓ Saved JSON: crop_Componenets_1.transformed744.json
# ✓ Saved mask: crop_Componenets_1.transformed744.npy
# ✓ Saved JSON: crop_Componenets_1.transformed745.json
# ✓ Saved mask: crop_Componenets_1.transformed745.npy
# ✓ Saved JSON: crop_Componenets_1.transformed746.json
# ✓ Saved mask: crop_Componenets_1.transformed746.npy
# ✓ Saved JSON: crop_Componenets_1.transformed747.json
# ✓ Saved mask: crop_Componenets_1.transformed747.npy
# ✓ Saved JSON: crop_Componenets_1.transformed748.json
# ✓ Saved mask: crop_Componenets_1.transformed748.npy
# ✓ Saved JSON: crop_Componenets_1.transformed749.json
# ✓ Saved mask: crop_Componenets_1.transformed749.npy
# ✓ Saved JSON: crop_Componenets_1.transformed750.json
# ✓ Saved mask: crop_Componenets_1.transformed750.npy
# ✓ Saved JSON: crop_Componenets_1.transformed751.json
# ✓ Saved mask: crop_Componenets_1.transformed751.npy
# ✓ Saved JSON: crop_Componenets_1.transformed752.json
# ✓ Saved mask: crop_Componenets_1.transformed752.npy
# ✓ Saved JSON: crop_Componenets_1.transformed753.json
# ✓ Saved mask: crop_Componenets_1.transformed753.npy
# ✓ Saved JSON: crop_Componenets_1.transformed754.json
# ✓ Saved mask: crop_Componenets_1.transformed754.npy
# ✓ Saved JSON: crop_Componenets_1.transformed755.json
# ✓ Saved mask: crop_Componenets_1.transformed755.npy
# ✓ Saved JSON: crop_Componenets_1.transformed756.json
# ✓ Saved mask: crop_Componenets_1.transformed756.npy
# ✓ Saved JSON: crop_Componenets_1.transformed757.json
# ✓ Saved mask: crop_Componenets_1.transformed757.npy
# ✓ Saved JSON: crop_Componenets_1.transformed758.json
# ✓ Saved mask: crop_Componenets_1.transformed758.npy
# ✓ Saved JSON: crop_Componenets_1.transformed759.json
# ✓ Saved mask: crop_Componenets_1.transformed759.npy
# ✓ Saved JSON: crop_Componenets_1.transformed760.json
# ✓ Saved mask: crop_Componenets_1.transformed760.npy
# ✓ Saved JSON: crop_Componenets_1.transformed761.json
# ✓ Saved mask: crop_Componenets_1.transformed761.npy
# ✓ Saved JSON: crop_Componenets_1.transformed762.json
# ✓ Saved mask: crop_Componenets_1.transformed762.npy
# ✓ Saved JSON: crop_Componenets_1.transformed763.json
# ✓ Saved mask: crop_Componenets_1.transformed763.npy
# ✓ Saved JSON: crop_Componenets_1.transformed764.json
# ✓ Saved mask: crop_Componenets_1.transformed764.npy
# ✓ Saved JSON: crop_Componenets_1.transformed765.json
# ✓ Saved mask: crop_Componenets_1.transformed765.npy
# ✓ Saved JSON: crop_Componenets_1.transformed766.json
# ✓ Saved mask: crop_Componenets_1.transformed766.npy
# ✓ Saved JSON: crop_Componenets_1.transformed767.json
# ✓ Saved mask: crop_Componenets_1.transformed767.npy
# ✓ Saved JSON: crop_Componenets_1.transformed768.json
# ✓ Saved mask: crop_Componenets_1.transformed768.npy
# ✓ Saved JSON: crop_Componenets_1.transformed769.json
# ✓ Saved mask: crop_Componenets_1.transformed769.npy
# ✓ Saved JSON: crop_Componenets_1.transformed770.json
# ✓ Saved mask: crop_Componenets_1.transformed770.npy
# ✓ Saved JSON: crop_Componenets_1.transformed771.json
# ✓ Saved mask: crop_Componenets_1.transformed771.npy
# ✓ Saved JSON: crop_Componenets_1.transformed772.json
# ✓ Saved mask: crop_Componenets_1.transformed772.npy
# ✓ Saved JSON: crop_Componenets_1.transformed773.json
# ✓ Saved mask: crop_Componenets_1.transformed773.npy
# ✓ Saved JSON: crop_Componenets_1.transformed774.json
# ✓ Saved mask: crop_Componenets_1.transformed774.npy
# ✓ Saved JSON: crop_Componenets_1.transformed775.json
# ✓ Saved mask: crop_Componenets_1.transformed775.npy
# ✓ Saved JSON: crop_Componenets_1.transformed776.json
# ✓ Saved mask: crop_Componenets_1.transformed776.npy
# ✓ Saved JSON: crop_Componenets_1.transformed777.json
# ✓ Saved mask: crop_Componenets_1.transformed777.npy
# ✓ Saved JSON: crop_Componenets_1.transformed778.json
# ✓ Saved mask: crop_Componenets_1.transformed778.npy
# ✓ Saved JSON: crop_Componenets_1.transformed779.json
# ✓ Saved mask: crop_Componenets_1.transformed779.npy
# ✓ Saved JSON: crop_Componenets_1.transformed780.json
# ✓ Saved mask: crop_Componenets_1.transformed780.npy
# ✓ Saved JSON: crop_Componenets_1.transformed781.json
# ✓ Saved mask: crop_Componenets_1.transformed781.npy
# ✓ Saved JSON: crop_Componenets_1.transformed782.json
# ✓ Saved mask: crop_Componenets_1.transformed782.npy
# ✓ Saved JSON: crop_Componenets_1.transformed783.json
# ✓ Saved mask: crop_Componenets_1.transformed783.npy
# ✓ Saved JSON: crop_Componenets_1.transformed784.json
# ✓ Saved mask: crop_Componenets_1.transformed784.npy
# ✓ Saved JSON: crop_Componenets_1.transformed785.json
# ✓ Saved mask: crop_Componenets_1.transformed785.npy
# ✓ Saved JSON: crop_Componenets_1.transformed786.json
# ✓ Saved mask: crop_Componenets_1.transformed786.npy
# ✓ Saved JSON: crop_Componenets_1.transformed787.json
# ✓ Saved mask: crop_Componenets_1.transformed787.npy
# ✓ Saved JSON: crop_Componenets_1.transformed788.json
# ✓ Saved mask: crop_Componenets_1.transformed788.npy
# ✓ Saved JSON: crop_Componenets_1.transformed789.json
# ✓ Saved mask: crop_Componenets_1.transformed789.npy
# ✓ Saved JSON: crop_Componenets_1.transformed790.json
# ✓ Saved mask: crop_Componenets_1.transformed790.npy
# ✓ Saved JSON: crop_Componenets_1.transformed791.json
# ✓ Saved mask: crop_Componenets_1.transformed791.npy
# ✓ Saved JSON: crop_Componenets_1.transformed792.json
# ✓ Saved mask: crop_Componenets_1.transformed792.npy
# ✓ Saved JSON: crop_Componenets_1.transformed793.json
# ✓ Saved mask: crop_Componenets_1.transformed793.npy
# ✓ Saved JSON: crop_Componenets_1.transformed794.json
# ✓ Saved mask: crop_Componenets_1.transformed794.npy
# ✓ Saved JSON: crop_Componenets_1.transformed795.json
# ✓ Saved mask: crop_Componenets_1.transformed795.npy
# ✓ Saved JSON: crop_Componenets_1.transformed796.json
# ✓ Saved mask: crop_Componenets_1.transformed796.npy
# ✓ Saved JSON: crop_Componenets_1.transformed797.json
# ✓ Saved mask: crop_Componenets_1.transformed797.npy
# ✓ Saved JSON: crop_Componenets_1.transformed798.json
# ✓ Saved mask: crop_Componenets_1.transformed798.npy
# ✓ Saved JSON: crop_Componenets_1.transformed799.json
# ✓ Saved mask: crop_Componenets_1.transformed799.npy
# ✓ Saved JSON: crop_Componenets_1.transformed800.json
# ✓ Saved mask: crop_Componenets_1.transformed800.npy
# ✓ Saved JSON: crop_Componenets_1.transformed801.json
# ✓ Saved mask: crop_Componenets_1.transformed801.npy
# ✓ Saved JSON: crop_Componenets_1.transformed802.json
# ✓ Saved mask: crop_Componenets_1.transformed802.npy
# ✓ Saved JSON: crop_Componenets_1.transformed803.json
# ✓ Saved mask: crop_Componenets_1.transformed803.npy
# ✓ Saved JSON: crop_Componenets_1.transformed804.json
# ✓ Saved mask: crop_Componenets_1.transformed804.npy
# ✓ Saved JSON: crop_Componenets_1.transformed805.json
# ✓ Saved mask: crop_Componenets_1.transformed805.npy
# ✓ Saved JSON: crop_Componenets_1.transformed806.json
# ✓ Saved mask: crop_Componenets_1.transformed806.npy
# ✓ Saved JSON: crop_Componenets_1.transformed807.json
# ✓ Saved mask: crop_Componenets_1.transformed807.npy
# ✓ Saved JSON: crop_Componenets_1.transformed808.json
# ✓ Saved mask: crop_Componenets_1.transformed808.npy
# ✓ Saved JSON: crop_Componenets_1.transformed809.json
# ✓ Saved mask: crop_Componenets_1.transformed809.npy
# ✓ Saved JSON: crop_Componenets_1.transformed810.json
# ✓ Saved mask: crop_Componenets_1.transformed810.npy
# ✓ Saved JSON: crop_Componenets_1.transformed811.json
# ✓ Saved mask: crop_Componenets_1.transformed811.npy
# ✓ Saved JSON: crop_Componenets_1.transformed812.json
# ✓ Saved mask: crop_Componenets_1.transformed812.npy
# ✓ Saved JSON: crop_Componenets_1.transformed813.json
# ✓ Saved mask: crop_Componenets_1.transformed813.npy
# ✓ Saved JSON: crop_Componenets_1.transformed814.json
# ✓ Saved mask: crop_Componenets_1.transformed814.npy
# ✓ Saved JSON: crop_Componenets_1.transformed815.json
# ✓ Saved mask: crop_Componenets_1.transformed815.npy
# ✓ Saved JSON: crop_Componenets_1.transformed816.json
# ✓ Saved mask: crop_Componenets_1.transformed816.npy
# ✓ Saved JSON: crop_Componenets_1.transformed817.json
# ✓ Saved mask: crop_Componenets_1.transformed817.npy
# ✓ Saved JSON: crop_Componenets_1.transformed818.json
# ✓ Saved mask: crop_Componenets_1.transformed818.npy
# ✓ Saved JSON: crop_Componenets_1.transformed819.json
# ✓ Saved mask: crop_Componenets_1.transformed819.npy
# ✓ Saved JSON: crop_Componenets_1.transformed820.json
# ✓ Saved mask: crop_Componenets_1.transformed820.npy
# ✓ Saved JSON: crop_Componenets_1.transformed821.json
# ✓ Saved mask: crop_Componenets_1.transformed821.npy
# ✓ Saved JSON: crop_Componenets_1.transformed822.json
# ✓ Saved mask: crop_Componenets_1.transformed822.npy
# ✓ Saved JSON: crop_Componenets_1.transformed823.json
# ✓ Saved mask: crop_Componenets_1.transformed823.npy
# ✓ Saved JSON: crop_Componenets_1.transformed824.json
# ✓ Saved mask: crop_Componenets_1.transformed824.npy
# ✓ Saved JSON: crop_Componenets_1.transformed825.json
# ✓ Saved mask: crop_Componenets_1.transformed825.npy
# ✓ Saved JSON: crop_Componenets_1.transformed826.json
# ✓ Saved mask: crop_Componenets_1.transformed826.npy
# ✓ Saved JSON: crop_Componenets_1.transformed827.json
# ✓ Saved mask: crop_Componenets_1.transformed827.npy
# ✓ Saved JSON: crop_Componenets_1.transformed828.json
# ✓ Saved mask: crop_Componenets_1.transformed828.npy
# ✓ Saved JSON: crop_Componenets_1.transformed829.json
# ✓ Saved mask: crop_Componenets_1.transformed829.npy
# ✓ Saved JSON: crop_Componenets_1.transformed830.json
# ✓ Saved mask: crop_Componenets_1.transformed830.npy
# ✓ Saved JSON: crop_Componenets_1.transformed831.json
# ✓ Saved mask: crop_Componenets_1.transformed831.npy
# ✓ Saved JSON: crop_Componenets_1.transformed832.json
# ✓ Saved mask: crop_Componenets_1.transformed832.npy
# ✓ Saved JSON: crop_Componenets_1.transformed833.json
# ✓ Saved mask: crop_Componenets_1.transformed833.npy
# ✓ Saved JSON: crop_Componenets_1.transformed834.json
# ✓ Saved mask: crop_Componenets_1.transformed834.npy
# ✓ Saved JSON: crop_Componenets_1.transformed835.json
# ✓ Saved mask: crop_Componenets_1.transformed835.npy
# ✓ Saved JSON: crop_Componenets_1.transformed836.json
# ✓ Saved mask: crop_Componenets_1.transformed836.npy
# ✓ Saved JSON: crop_Componenets_1.transformed837.json
# ✓ Saved mask: crop_Componenets_1.transformed837.npy
# ✓ Saved JSON: crop_Componenets_1.transformed838.json
# ✓ Saved mask: crop_Componenets_1.transformed838.npy
# ✓ Saved JSON: crop_Componenets_1.transformed839.json
# ✓ Saved mask: crop_Componenets_1.transformed839.npy
# ✓ Saved JSON: crop_Componenets_1.transformed840.json
# ✓ Saved mask: crop_Componenets_1.transformed840.npy
# ✓ Saved JSON: crop_Componenets_1.transformed841.json
# ✓ Saved mask: crop_Componenets_1.transformed841.npy
# ✓ Saved JSON: crop_Componenets_1.transformed842.json
# ✓ Saved mask: crop_Componenets_1.transformed842.npy
# ✓ Saved JSON: crop_Componenets_1.transformed843.json
# ✓ Saved mask: crop_Componenets_1.transformed843.npy
# ✓ Saved JSON: crop_Componenets_1.transformed844.json
# ✓ Saved mask: crop_Componenets_1.transformed844.npy
# ✓ Saved JSON: crop_Componenets_1.transformed845.json
# ✓ Saved mask: crop_Componenets_1.transformed845.npy
# ✓ Saved JSON: crop_Componenets_1.transformed846.json
# ✓ Saved mask: crop_Componenets_1.transformed846.npy
# ✓ Saved JSON: crop_Componenets_1.transformed847.json
# ✓ Saved mask: crop_Componenets_1.transformed847.npy
# ✓ Saved JSON: crop_Componenets_1.transformed848.json
# ✓ Saved mask: crop_Componenets_1.transformed848.npy
# ✓ Saved JSON: crop_Componenets_1.transformed849.json
# ✓ Saved mask: crop_Componenets_1.transformed849.npy
# ✓ Saved JSON: crop_Componenets_1.transformed850.json
# ✓ Saved mask: crop_Componenets_1.transformed850.npy
# ✓ Saved JSON: crop_Componenets_1.transformed851.json
# ✓ Saved mask: crop_Componenets_1.transformed851.npy
# ✓ Saved JSON: crop_Componenets_1.transformed852.json
# ✓ Saved mask: crop_Componenets_1.transformed852.npy
# ✓ Saved JSON: crop_Componenets_1.transformed853.json
# ✓ Saved mask: crop_Componenets_1.transformed853.npy
# ✓ Saved JSON: crop_Componenets_1.transformed854.json
# ✓ Saved mask: crop_Componenets_1.transformed854.npy
# ✓ Saved JSON: crop_Componenets_1.transformed855.json
# ✓ Saved mask: crop_Componenets_1.transformed855.npy
# ✓ Saved JSON: crop_Componenets_1.transformed856.json
# ✓ Saved mask: crop_Componenets_1.transformed856.npy
# ✓ Saved JSON: crop_Componenets_1.transformed857.json
# ✓ Saved mask: crop_Componenets_1.transformed857.npy
# ✓ Saved JSON: crop_Componenets_1.transformed858.json
# ✓ Saved mask: crop_Componenets_1.transformed858.npy
# ✓ Saved JSON: crop_Componenets_1.transformed859.json
# ✓ Saved mask: crop_Componenets_1.transformed859.npy
# ✓ Saved JSON: crop_Componenets_1.transformed860.json
# ✓ Saved mask: crop_Componenets_1.transformed860.npy
# ✓ Saved JSON: crop_Componenets_1.transformed861.json
# ✓ Saved mask: crop_Componenets_1.transformed861.npy
# ✓ Saved JSON: crop_Componenets_1.transformed862.json
# ✓ Saved mask: crop_Componenets_1.transformed862.npy
# ✓ Saved JSON: crop_Componenets_1.transformed863.json
# ✓ Saved mask: crop_Componenets_1.transformed863.npy
# ✓ Saved JSON: crop_Componenets_1.transformed864.json
# ✓ Saved mask: crop_Componenets_1.transformed864.npy
# ✓ Saved JSON: crop_Componenets_1.transformed865.json
# ✓ Saved mask: crop_Componenets_1.transformed865.npy
# ✓ Saved JSON: crop_Componenets_1.transformed866.json
# ✓ Saved mask: crop_Componenets_1.transformed866.npy
# ✓ Saved JSON: crop_Componenets_1.transformed867.json
# ✓ Saved mask: crop_Componenets_1.transformed867.npy
# ✓ Saved JSON: crop_Componenets_1.transformed868.json
# ✓ Saved mask: crop_Componenets_1.transformed868.npy
# ✓ Saved JSON: crop_Componenets_1.transformed869.json
# ✓ Saved mask: crop_Componenets_1.transformed869.npy
# ✓ Saved JSON: crop_Componenets_1.transformed870.json
# ✓ Saved mask: crop_Componenets_1.transformed870.npy
# ✓ Saved JSON: crop_Componenets_1.transformed871.json
# ✓ Saved mask: crop_Componenets_1.transformed871.npy
# ✓ Saved JSON: crop_Componenets_1.transformed872.json
# ✓ Saved mask: crop_Componenets_1.transformed872.npy
# ✓ Saved JSON: crop_Componenets_1.transformed873.json
# ✓ Saved mask: crop_Componenets_1.transformed873.npy
# ✓ Saved JSON: crop_Componenets_1.transformed874.json
# ✓ Saved mask: crop_Componenets_1.transformed874.npy
# ✓ Saved JSON: crop_Componenets_1.transformed875.json
# ✓ Saved mask: crop_Componenets_1.transformed875.npy
# ✓ Saved JSON: crop_Componenets_1.transformed876.json
# ✓ Saved mask: crop_Componenets_1.transformed876.npy
# ✓ Saved JSON: crop_Componenets_1.transformed877.json
# ✓ Saved mask: crop_Componenets_1.transformed877.npy
# ✓ Saved JSON: crop_Componenets_1.transformed878.json
# ✓ Saved mask: crop_Componenets_1.transformed878.npy
# ✓ Saved JSON: crop_Componenets_1.transformed879.json
# ✓ Saved mask: crop_Componenets_1.transformed879.npy
# ✓ Saved JSON: crop_Componenets_1.transformed880.json
# ✓ Saved mask: crop_Componenets_1.transformed880.npy
# ✓ Saved JSON: crop_Componenets_1.transformed881.json
# ✓ Saved mask: crop_Componenets_1.transformed881.npy
# ✓ Saved JSON: crop_Componenets_1.transformed882.json
# ✓ Saved mask: crop_Componenets_1.transformed882.npy
# ✓ Saved JSON: crop_Componenets_1.transformed883.json
# ✓ Saved mask: crop_Componenets_1.transformed883.npy
# ✓ Saved JSON: crop_Componenets_1.transformed884.json
# ✓ Saved mask: crop_Componenets_1.transformed884.npy
# ✓ Saved JSON: crop_Componenets_1.transformed885.json
# ✓ Saved mask: crop_Componenets_1.transformed885.npy
# ✓ Saved JSON: crop_Componenets_1.transformed886.json
# ✓ Saved mask: crop_Componenets_1.transformed886.npy
# ✓ Saved JSON: crop_Componenets_1.transformed887.json
# ✓ Saved mask: crop_Componenets_1.transformed887.npy
# ✓ Saved JSON: crop_Componenets_1.transformed888.json
# ✓ Saved mask: crop_Componenets_1.transformed888.npy
# ✓ Saved JSON: crop_Componenets_1.transformed889.json
# ✓ Saved mask: crop_Componenets_1.transformed889.npy
# ✓ Saved JSON: crop_Componenets_1.transformed890.json
# ✓ Saved mask: crop_Componenets_1.transformed890.npy
